# %% [markdown]
# <a href="https://colab.research.google.com/github/TolulopeOyejide/DataAnalysisProject5/blob/main/Probability_and_Stastitics_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Introduction to Stastitics in Python

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-50c51f0f-f88b-4608-a1cd-a9f29427768c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-50c51f0f-f88b-4608-a1cd-a9f29427768c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
df_1  = pd.read_csv("wnba.csv")
df_1.head()
# Out:
#               Name Team  Pos  Height  Weight        BMI Birth_Place  \
# 0    Aerial Powers  DAL    F     183    71.0  21.200991          US
# 1      Alana Beard   LA  G/F     185    73.0  21.329438          US
# 2     Alex Bentley  CON    G     170    69.0  23.875433          US
# 3  Alex Montgomery  SAN  G/F     185    84.0  24.543462          US
# 4     Alexis Jones  MIN    G     175    78.0  25.469388          US
#
#            Birthdate  Age         College  ... OREB  DREB  REB  AST  STL  BLK  \
# 0   January 17, 1994   23  Michigan State  ...    6    22   28   12    3    6
# 1       May 14, 1982   35            Duke  ...   19    82  101   72   63   13
# 2   October 27, 1990   26      Penn State  ...    4    36   40   78   22    3
# 3  December 11, 1988   28    Georgia Tech  ...   35   134  169   65   20   10
# 4     August 5, 1994   23          Baylor  ...    3     9   12   12    7    0
#
#    TO  PTS  DD2  TD3
# 0  12   93    0    0
# 1  40  217    0    0
# ...

# %%
df_1.columns
# Out:
# Index(['Name', 'Team', 'Pos', 'Height', 'Weight', 'BMI', 'Birth_Place',
#        'Birthdate', 'Age', 'College', 'Experience', 'Games Played', 'MIN',
#        'FGM', 'FGA', 'FG%', '15:00', '3PA', '3P%', 'FTM', 'FTA', 'FT%', 'OREB',
#        'DREB', 'REB', 'AST', 'STL', 'BLK', 'TO', 'PTS', 'DD2', 'TD3'],
#       dtype='object')

# %%
df_1['Games Played'].head()
# Out:
# 0     8
# 1    30
# 2    26
# 3    31
# 4    24
# Name: Games Played, dtype: int64

# %%
parameter = df_1['Games Played'].max()
parameter
# Out:
# 32

# %%
sample = df_1.sample() #Randomly picking sample
sample
# Out:
#            Name Team Pos  Height  Weight       BMI Birth_Place     Birthdate  \
# 66  Jewell Loyd  SEA   G     178    67.0  21.14632          US  May 10, 1993
#
#     Age     College  ... OREB  DREB  REB  AST  STL  BLK  TO  PTS  DD2  TD3
# 66   24  Notre Dame  ...   50   139  189   46   18   50  57  268    4    0
#
# [1 rows x 32 columns]

# %%
stastitic = sample['Games Played'].max()
stastitic
# Out:
# 29

# %%
Sample_Error = parameter - stastitic
Sample_Error
# Out:
# 3

# %% [markdown]
# Random Sampling for accurate representation of the population

# %%
random_sample = df_1.sample(30, random_state = 1) #Randomly picking sample
random_sample
# Out:
#                        Name Team  Pos  Height  Weight        BMI Birth_Place  \
# 78           Keisha Hampton  CHI    F     185    78.0  22.790358          US
# 116            Saniya Chong  DAL    G     173    64.0  21.383942          US
# 31           Carolyn Swords  SEA    C     198    95.0  24.232221          US
# 5           Alexis Peterson  SEA    G     170    63.0  21.799308          US
# 125         Stefanie Dolson  CHI    C     196    97.0  25.249896          US
# 45            Diana Taurasi  PHO    G     183    74.0  22.096808          US
# 14             Aneika Henry  ATL  F/C     193    87.0  23.356332          JM
# 44         Devereaux Peters  IND    F     188    79.0  22.351743          US
# 73   Karima Christmas-Kelly  DAL  G/F     183    82.0  24.485652          US
# 89            Lynetta Kizer  CON    C     193   104.0  27.920213          US
# 130            Sydney Wiese   LA    G     183    68.0  20.305175          US
# ...

# %% [markdown]
# Statified Sampling

# %%
df_1['Pos'].unique()
# Out:
# array(['F', 'G/F', 'G', 'C', 'F/C'], dtype=object)

# %% [markdown]
# Sampling:
# 1. Simple random sampling.
# 2. Stratified Sampling.
# 3. Cluster Sampling.

# %% [markdown]
# ### Variable in Stastitics

# %%
df_1.shape
# Out:
# (143, 32)

# %% [markdown]
# ###Frequency Disribution

# %%
df_1['Pos'].value_counts()
# Out:
# G      60
# F      33
# C      25
# G/F    13
# F/C    12
# Name: Pos, dtype: int64

# %%
df_1['Height'].value_counts().sort_index()
# Out:
# 165     1
# 168     2
# 170     6
# 173    11
# 175    16
# 178     8
# 180     7
# 183    11
# 185    15
# 188    20
# 191    11
# 193    18
# 196     9
# 198     5
# 201     2
# 206     1
# Name: Height, dtype: int64

# %%
def make_pts_ordinal(row):
  if row['PTS'] <= 20:
    return'very few points'
  if (20 < row['PTS'] <= 80):
    return'few points'
  if (80 < row['PTS'] <= 150):
    return'many, but below average'
  if (150 < row['PTS'] <= 300):
    return'average number of points'
  if (300 < row['PTS'] <= 450):
    return 'much more than average'

# %%
df_1['PTS_ordinal_scale'] = df_1.apply(make_pts_ordinal, axis = 1 )

# %%
df_1[['Name', 'PTS', 'PTS_ordinal_scale']].head().sort_index()
# Out:
#               Name  PTS         PTS_ordinal_scale
# 0    Aerial Powers   93   many, but below average
# 1      Alana Beard  217  average number of points
# 2     Alex Bentley  218  average number of points
# 3  Alex Montgomery  188  average number of points
# 4     Alexis Jones   50                few points

# %% [markdown]
# ### Proportion and Percentages

# %%
# Computing Proportions in Pandas
df_1['Pos'].value_counts()/len(df_1)
# Out:
# G      0.419580
# F      0.230769
# C      0.174825
# G/F    0.090909
# F/C    0.083916
# Name: Pos, dtype: float64

# %%
#Another Method for computing proportions
df_1['Pos'].value_counts(normalize = True)
# Out:
# G      0.419580
# F      0.230769
# C      0.174825
# G/F    0.090909
# F/C    0.083916
# Name: Pos, dtype: float64

# %%
#Computing Percentages
df_1['Pos'].value_counts(normalize = True)* 100
# Out:
# G      41.958042
# F      23.076923
# C      17.482517
# G/F     9.090909
# F/C     8.391608
# Name: Pos, dtype: float64

# %%
# PERCENTILES

from scipy.stats import percentileofscore

# %%
# What percentage of players are 23 years or younger?
percentileofscore(a = df_1['Age'], score = 23, kind = 'weak' )
# kind is used to find the percentage of values that are equal or less than the value we specify in the score parameter.
# Out:
# 18.88111888111888

# %%
#Finding percentile using pandas
df_1['Age'].describe().iloc[3:]
# Out:
# min    21.0
# 25%    24.0
# 50%    27.0
# 75%    30.0
# max    36.0
# Name: Age, dtype: float64

# %% [markdown]
# ## Grouped Frequency Distribution Table

# %%
df_1['Weight'].value_counts().sort_index()
# Out:
# 55.0      1
# 57.0      1
# 58.0      1
# 59.0      2
# 62.0      1
# 63.0      3
# 64.0      5
# 65.0      4
# 66.0      8
# 67.0      1
# 68.0      2
# 69.0      2
# 70.0      3
# 71.0      2
# 73.0      6
# 74.0      4
# 75.0      4
# 76.0      4
# 77.0     10
# 78.0      5
# 79.0      6
# 80.0      3
# 81.0      5
# 82.0      4
# 83.0      4
# 84.0      9
# 85.0      2
# 86.0      7
# 87.0      6
# 88.0      6
# 89.0      3
# 90.0      2
# 91.0      3
# 93.0      3
# 95.0      2
# 96.0      2
# 97.0      1
# 104.0     2
# 108.0     1
# 113.0     2
# Name: Weight, dtype: int64

# %%
df_1['Weight'].value_counts(bins = 10).sort_index()
# Out:
# (54.941, 60.8]     5
# (60.8, 66.6]      21
# (66.6, 72.4]      10
# (72.4, 78.2]      33
# (78.2, 84.0]      31
# (84.0, 89.8]      24
# (89.8, 95.6]      10
# (95.6, 101.4]      3
# (101.4, 107.2]     2
# (107.2, 113.0]     3
# Name: Weight, dtype: int64

# %%
intervals = pd.interval_range(start = 0, end = 600, freq = 100)
intervals
# Out:
# IntervalIndex([(0, 100], (100, 200], (200, 300], (300, 400], (400, 500], (500, 600]], dtype='interval[int64, right]')

# %%
gr_freq_table = df_1["PTS"].value_counts(bins = intervals).sort_index()
gr_freq_table
# Out:
# (0, 100]      49
# (100, 200]    28
# (200, 300]    32
# (300, 400]    17
# (400, 500]    10
# (500, 600]     7
# Name: PTS, dtype: int64

# %%
df_1['Height'].value_counts()[175]
#The height of 175ch has a frequency of 16 in the distribution
# Out:
# 16

# %%
import matplotlib.pyplot as plt

# %%
df_1['Pos'].value_counts().plot.bar()
plt.show()

# %% [markdown]
# ## Grouped Bar Plots

# %%
import seaborn as sns

# %%
df_1.columns
# Out:
# Index(['Name', 'Team', 'Pos', 'Height', 'Weight', 'BMI', 'Birth_Place',
#        'Birthdate', 'Age', 'College', 'Experience', 'Games Played', 'MIN',
#        'FGM', 'FGA', 'FG%', '15:00', '3PA', '3P%', 'FTM', 'FTA', 'FT%', 'OREB',
#        'DREB', 'REB', 'AST', 'STL', 'BLK', 'TO', 'PTS', 'DD2', 'TD3',
#        'PTS_ordinal_scale'],
#       dtype='object')

# %%
sns.countplot(x = 'Age', hue = 'Pos', data = df_1)
plt.show()

# %%
df_1[df_1.Age >= 27]['MIN'].plot.hist(label = 'Old', legend = True)
df_1[df_1.Age < 27]['MIN'].plot.hist(label = 'Young', legend = True)
plt.show()

# %%
df_1[df_1.Age >= 27]['MIN'].plot.hist(histtype = 'step', label = 'Old', legend = True)
df_1[df_1.Age < 27]['MIN'].plot.hist(histtype = 'step', label = 'Young', legend = True)
plt.show()

# %%
# Kernel density estimated plot
df_1[df_1.Age >= 27]['MIN'].plot.kde( label = 'Old', legend = True)
df_1[df_1.Age < 27]['MIN'].plot.kde( label = 'Young', legend = True)
plt.show()

# We can use kernel density plots to get a much clear picture about the shape of
# shape of a distribution

# %%
sns.stripplot( x = 'Pos', y = 'Height', data = df_1, jitter = False)
plt.show()

# %%
sns.stripplot( x = 'Pos', y = 'Height', data = df_1, jitter = True)
plt.show()

# %%
sns.boxplot(x = 'Pos', y = 'Height', data = df_1)
plt.show()

# %% [markdown]
# # INTERMEDIATE STASTITICS

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-6f04bdd6-3a67-4fdf-b768-73d8fb9c9c4f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6f04bdd6-3a67-4fdf-b768-73d8fb9c9c4f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
houses = pd.read_csv('AmesHousing_1.txt', delimiter='\t')
houses
# Out:
#       Order        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 0         1  526301100           20        RL         141.0    131770   Pave
# 1         2  526350040           20        RH          80.0     11622   Pave
# 2         3  526351010           20        RL          81.0     14267   Pave
# 3         4  526353030           20        RL          93.0     11160   Pave
# 4         5  527105010           60        RL          74.0     13830   Pave
# ...     ...        ...          ...       ...           ...       ...    ...
# 2925   2926  923275080           80        RL          37.0      7937   Pave
# 2926   2927  923276100           20        RL           NaN      8885   Pave
# 2927   2928  923400125           85        RL          62.0     10441   Pave
# 2928   2929  924100070           20        RL          77.0     10010   Pave
# 2929   2930  924151050           60        RL          74.0      9627   Pave
#
# ...

# %%
#Analysing the distribution of the Sales Price
houses['SalePrice'].describe()
# Out:
# count      2930.000000
# mean     180796.060068
# std       79886.692357
# min       12789.000000
# 25%      129500.000000
# 50%      160000.000000
# 75%      213500.000000
# max      755000.000000
# Name: SalePrice, dtype: float64

# %%
#Analysing the distribution of the Sales Price
houses['SalePrice'].describe()
# Out:
# count      2930.000000
# mean     180796.060068
# std       79886.692357
# min       12789.000000
# 25%      129500.000000
# 50%      160000.000000
# 75%      213500.000000
# max      755000.000000
# Name: SalePrice, dtype: float64

# %%
houses['SalePrice'].mean()
# Out:
# 180796.0600682594

# %%
#Draw a vertical line corresponding to the population mean
means = []

for i in range(10000):
  sample = houses['SalePrice'].sample(3, random_state = i)
  means.append(sample.mean())

plt.hist(means)
plt.axvline(houses['SalePrice'].mean())

# %%
houses['SalePrice'].plot.kde(xlim=(houses['SalePrice'].min(), houses['SalePrice'].max()))
plt.axvline(150000, color='green', label='Mode')
plt.axvline(houses['SalePrice'].median(), color='black', label='Median')
plt.axvline(houses['SalePrice'].mean(), color='orange', label='Mean')
plt.legend()
plt.show()

# %%
houses.columns
# Out:
# Index(['Order', 'PID', 'MS SubClass', 'MS Zoning', 'Lot Frontage', 'Lot Area',
#        'Street', 'Alley', 'Lot Shape', 'Land Contour', 'Utilities',
#        'Lot Config', 'Land Slope', 'Neighborhood', 'Condition 1',
#        'Condition 2', 'Bldg Type', 'House Style', 'Overall Qual',
#        'Overall Cond', 'Year Built', 'Year Remod/Add', 'Roof Style',
#        'Roof Matl', 'Exterior 1st', 'Exterior 2nd', 'Mas Vnr Type',
#        'Mas Vnr Area', 'Exter Qual', 'Exter Cond', 'Foundation', 'Bsmt Qual',
#        'Bsmt Cond', 'Bsmt Exposure', 'BsmtFin Type 1', 'BsmtFin SF 1',
#        'BsmtFin Type 2', 'BsmtFin SF 2', 'Bsmt Unf SF', 'Total Bsmt SF',
#        'Heating', 'Heating QC', 'Central Air', 'Electrical', '1st Flr SF',
#        '2nd Flr SF', 'Low Qual Fin SF', 'Gr Liv Area', 'Bsmt Full Bath',
#        'Bsmt Half Bath', 'Full Bath', 'Half Bath', 'Bedroom AbvGr',
#        'Kitchen AbvGr', 'Kitchen Qual', 'TotRms AbvGrd', 'Functional',
# ...

# %%
houses['Year Built'].plot.kde(xlim=(houses['Year Built'].min(), houses['Year Built'].max()))
plt.axvline(150000, color='green', label='Mode')
plt.axvline(houses['Year Built'].median(), color='black', label='Median')
plt.axvline(houses['Year Built'].mean(), color='orange', label='Mean')
plt.legend()
plt.show()

# %% [markdown]
# ## MEASURE OF VARIABILITY

# %%
import numpy as np
mean = houses['SalePrice'].mean()
st_dev = np.std(houses['SalePrice'])

houses['SalePrice'].plot.hist()
plt.axvline(mean, color='black', label='Mean')
plt.axvline(mean - st_dev, color='red', label='One Std Dev Below')
plt.axvline(mean + st_dev, color='violet', label='One Std Dev Above')
plt.legend()
plt.show()

# %% [markdown]
# ## Z Scores

# %%
def z_score(value, array, bessel = 0):
  mean = sum(array) / len(array)

  from numpy import std
  st_dev = std(array, ddof = bessel)

  distance = value - mean
  z = distance /st_dev

  return z

# %%
houses['SalePrice'].plot.kde(xlim = (houses['SalePrice'].min(), houses['SalePrice'].max()))
# Out:
# <Axes: ylabel='Density'>
